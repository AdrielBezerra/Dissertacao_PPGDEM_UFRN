# %%
import pandas as pd
import pandas_profiling
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sns
import altair as alt
import missingno as msno

# %%
graf = pd.read_csv("ENADE2017V13W1.csv", sep= ";", na_values=" ")

# %%
graf.tail(10)
# Out:
#         SubjID  IDADE  SEXO  RACA  ...  DIFICULDADEPE  REGIAO  IES  MODALIDADE
# 431697    6208      5     2   2.0  ...            NaN       3    1           2
# 431698    6208      4     2   2.0  ...            NaN       3    1           2
# 431699    6208      6     2   1.0  ...            NaN       3    1           2
# 431700    6208      4     1   1.0  ...            NaN       3    1           2
# 431701    6208      6     2   NaN  ...            NaN       3    1           2
# 431702    6208      3     2   1.0  ...            NaN       3    1           2
# 431703    6208      3     2   2.0  ...            NaN       3    1           2
# 431704    6208      2     2   2.0  ...            NaN       3    1           2
# 431705    6208      6     1   2.0  ...            NaN       3    1           2
# 431706    6208      5     1   NaN  ...            NaN       3    1           2
#
# [10 rows x 25 columns]

# %%
graf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 431707 entries, 0 to 431706
# Data columns (total 25 columns):
# SubjID           431707 non-null int64
# IDADE            431707 non-null int64
# SEXO             431707 non-null int64
# RACA             380239 non-null float64
# MORAD            380239 non-null float64
# ESCPAI           380239 non-null float64
# ESCMAE           380239 non-null float64
# LIVROS           380239 non-null float64
# DIFICULT         380239 non-null float64
# MOTIVO           380239 non-null float64
# INCENTIVO        380239 non-null float64
# RENDA            380239 non-null float64
# FINANC           380239 non-null float64
# ACADEMIC         380239 non-null float64
# PERMAN           380239 non-null float64
# EXTERIOR         380239 non-null float64
# AFIRMATIVA       380239 non-null float64
# TRAB             380239 non-null float64
# ENSMED           380239 non-null float64
# NOTA             333194 non-null float64
# ...

# %%
graf.isnull().sum()
# Out:
# SubjID               0
# IDADE                0
# SEXO                 0
# RACA             51468
# MORAD            51468
# ESCPAI           51468
# ESCMAE           51468
# LIVROS           51468
# DIFICULT         51468
# MOTIVO           51468
# INCENTIVO        51468
# RENDA            51468
# FINANC           51468
# ACADEMIC         51468
# PERMAN           51468
# EXTERIOR         51468
# AFIRMATIVA       51468
# TRAB             51468
# ENSMED           51468
# NOTA             98513
# DIFICULDADEPG    78681
# DIFICULDADEPE    78806
# REGIAO               0
# IES                  0
# MODALIDADE           0
# dtype: int64

# %%
graf.isnull().sum().plot(kind="bar")

# %%
sns.heatmap(graf.isnull(), cbar="false")

# %%
msno.matrix(graf)

# %%
msno.heatmap(graf)

# %%
df = pd.DataFrame(np.random.rand(10, 21), columns=['IDADE','SEXO','RACA','MORAD',
                                             'ESCPAI','ESCMAE','LIVROS','DIFICULT',
                                             'MOTIVO','INCENTIVO','RENDA','FINANC',
                                             'ACADEMIC','PERMAN','EXTERIOR','AFIRMATIVA',
                                             'TRAB','ENSMED','NOTA','DIFICULDADEPG',
                                             'DIFICULDADEPE'])

# %%
df.plot.box()

# %%
df.plot.area(stacked=False)

# %%
df2 = pd.DataFrame(np.random.rand(10, 7), columns=['ESCPAI','ESCMAE','LIVROS','DIFICULT',
                                             'MOTIVO','INCENTIVO','RENDA'])

# %%
df2.plot.area(stacked=False)
